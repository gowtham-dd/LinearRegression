# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham-dd/LinearRegression/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/diabetes.csv")

# %% [markdown]
# LINEAR REGRESSION
#
# y=mx+c

# %%
import numpy as np
x=[1,2,4,3,5]
y=[1,3,3,2,5]
mean_x = np.mean(x)
mean_y = np.mean(y)




def linreg(x,y):
# Using the formula to calculate b1 and b2
 numer = 0
 denom = 0
 m=len(x)
 for i in range(m):
   numer += (x[i] - mean_x) * (y[i] - mean_y)
   denom += (x[i] - mean_x) ** 2

 M = numer / denom
 c = mean_y - (M*mean_x)# c= y-mx
 print(M,c)
 return M,c


a=linreg(x,y)
print(a)
b=[]
for i in x:
 b.append((a[0]*i+a[1]))
 print(b)
# Out:
# 0.8 0.39999999999999947
# (np.float64(0.8), np.float64(0.39999999999999947))
# [np.float64(1.1999999999999995)]
# [np.float64(1.1999999999999995), np.float64(1.9999999999999996)]
# [np.float64(1.1999999999999995), np.float64(1.9999999999999996), np.float64(3.5999999999999996)]
# [np.float64(1.1999999999999995), np.float64(1.9999999999999996), np.float64(3.5999999999999996), np.float64(2.8)]
# [np.float64(1.1999999999999995), np.float64(1.9999999999999996), np.float64(3.5999999999999996), np.float64(2.8), np.float64(4.3999999999999995)]

# %%
import matplotlib.pyplot as plt

# Plot the actual points
plt.scatter(x, y, color='blue', label='Actual Points')
# Plot the linear regression line
plt.plot(x, b, color='red', label='Linear Regression')
# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Linear Regression Plot')
plt.legend()
# Display the plot
plt.show()

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/1.01.%20Simple%20linear%20regression.csv")
data
# data.shape
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
X = data.drop('GPA', axis=1)
y = data['GPA']
model = LinearRegression()
model.fit(X, y)
print(model.coef_)
print(model.intercept_)
print(model.predict([[1740]]))
# Out:
# [0.00165569]
# 0.2750402996602799
# [3.15593751]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression

X=data.drop('GPA',axis=1)# or use data['SAT'] x is future,future in only 2D format
y=data['GPA']#target may be 1D or 2D
model=LinearRegression()
model.fit(X,y)
print(model.coef_)#coef_ m value
print(model.intercept_)
print(model.predict([[1740]]))#for prediction
print(model.predict([[1200]]))
# Out:
# [0.00165569]
# 0.2750402996602799
# [3.15593751]
# [2.26186596]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
dia=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/diabetes.csv")
dia
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# prompt: Using dataframe dia: corelation heat map for dia

import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr_matrix = dia.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Diabetes Dataset')
plt.show()

# %%
#glucose,ski,bp features
#bmi - target

features=dia[['Glucose','BloodPressure','SkinThickness']]
target=dia['BMI']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)
#0.2 testing 20%

from sklearn.linear_model import LinearRegression
model=LinearRegression()

model.fit(X_train,y_train)
print(model.coef_)#m value
print(model.intercept_)#c inntercept / bias
print(model.predict([[148,72,35]]))
#y=mx+c
# Out:
# [0.04199383 0.06661283 0.17796625]
# 18.65393322225497
# [35.89396279]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

#save
filename='linear_regression_model.pkl'
pickle.dump(model,open(filename,'wb'))

#Load
loaded_model=pickle.load(open(filename,'rb'))
loaded_model.predict([[148,72,35]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35.89396279])

# %%
#Model Evaluation
#1. MAE - Model Absolute Error = avg(sum(Absolute(Predicted(y))))

model.predict(X_test)
print(model.score(X_test,y_test))
from sklearn.metrics import r2_score
r2_score(y_test,model.predict(X_test))
print(r2_score(y_test,model.predict(X_test)))
# Out:
# 0.2660449245050891
# 0.2660449245050891

# %%
from sklearn import metrics
import numpy as np
y_pred=model.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# Mean Absolute Error: 5.2034042673969285
# Mean Squared Error: 52.17352303953375
# Root Mean Squared Error: 7.2231241882951
# 0.2660449245050891

# %%
# !pip install gradio
import gradio as gr
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import pickle as pkl
# Load the pre-trained model
model = pkl.load(open('linear_regression_model.pkl', 'rb'))
def predict_bmi( glucose, blood_pressure,skinThickness):
  """Predicts BMI based on input features."""
  prediction = model.predict([[ glucose, blood_pressure,skinThickness]])
  return prediction[0]
# Create the Gradio interface
iface = gr.Interface(
    fn=predict_bmi,
    inputs=[
        gr.Number(label="Glucose"),
        gr.Number(label="BloodPressure"),
        gr.Number(label="SkinThickness")
    ],
    outputs=gr.Number(label="Predicted BMI"),
    title="Diabetes BMI Predictor",
    description="Enter the features to get the predicted BMI."
)
# Launch the interface
iface.launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://6870899fc75cee706f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6870899fc75cee706f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# PREPROESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.DataFrame({
  'Income': [15000, 1800, 120000, 10000],
  'Age': [25, 18, 42, 51],
  'Department': ['HR','Legal','Marketing','Management']
})

df_scaled = df.copy()
col_names = ['Income', 'Age']
features = df_scaled[col_names]
df_scaled
# Out:
#    Income  Age  Department
# 0   15000   25          HR
# 1    1800   18       Legal
# 2  120000   42   Marketing
# 3   10000   51  Management

# %%
import sklearn.preprocessing as preprocessing
from sklearn.preprocessing import MinMaxScaler
#x_scaled = (x – x_min)/(x_max – x_min)
scaler = MinMaxScaler(feature_range=(0,1))
df_scaled[col_names] = scaler.fit_transform(features.values)
df_scaled
# Out:
#      Income       Age  Department
# 0  0.111675  0.212121          HR
# 1  0.000000  0.000000       Legal
# 2  1.000000  0.727273   Marketing
# 3  0.069374  1.000000  Management

# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/USA_Housing.csv")
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# HOUSE PRICE PREDICTION

# %%
features=data[['Avg. Area Income', 'Avg. Area House Age', 'Area Population']]
target=data['Price']

#spli and scale

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
print(scaler.data_max_)
print(scaler.data_min_)
print(scaler.data_range_)
X_test=scaler.transform(X_test)


model.fit(X_train,y_train)
print(model.coef_)#m value
newdata=pd.DataFrame({'Avg. Area Income':[7876.46], 'Avg. Area House Age':[5.89], 'Area Population':[36163.25]})
newdata=scaler.transform(newdata)
print(model.intercept_)#c inntercept / bias
model.predict(newdata)
# Out:
# [1.04702724e+05 9.51908807e+00 6.96217134e+04]
# [1.77966312e+04 2.68304290e+00 1.72610686e+02]
# [8.69060931e+04 6.83604516e+00 6.94491027e+04]
# [1874064.88113358 1114344.80019349 1053998.98280058]
# -947300.3412780969
# array([-92240.46871014])

# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/USA_Housing.csv")
#print(data)

x = data[['Avg. Area Income', 'Avg. Area House Age',  'Area Population']]
y = data['Price']
#here split the train dataset(x_train,y_train) and test dataset(x_test,y_test), split 80% data to train dataset and 20% data to test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train) #here scale the  train data and find the min max value for x_train
print(scaler.data_max_)
print(scaler.data_min_)
print(scaler.data_range_)
x_test = scaler.transform(x_test) #here scale the test data  based on x_train min max value to scale the x_test


model = LinearRegression()
model.fit(x_train,y_train)
print('M value:',model.coef_) #m value
print('C value:',model.intercept_) #c value
new = pd.DataFrame({'Avg. Area Income': [79545.458574] , 'Avg. Area House Age': [5.682861],'Area Population': [23086.800503] })
new2 = scaler.transform(new)
print('predicted y value:',model.predict(new2))


from sklearn.metrics import r2_score
print(r2_score(y_test,model.predict(x_test)))
# Out:
# [1.04702724e+05 9.51908807e+00 6.96217134e+04]
# [1.77966312e+04 2.68304290e+00 3.28545054e+03]
# [8.69060931e+04 6.83604516e+00 6.63362628e+04]
# M value: [1877076.36416494 1122683.15714992 1008459.61925564]
# C value: -906747.9136777618
# predicted y value: [1220643.79632083]
# 0.7887749166682401

# %%
from sklearn.metrics import r2_score
r2_score(y_test,model.predict(x_test))
print('Accuracy in value:',r2_score(y_test,model.predict(x_test))*100,'%')
print('Accuracy in percentage',r2_score(y_test,model.predict(x_test)))
# Out:
# Accuracy in value: 78.877491666824 %
# Accuracy in percentage 0.7887749166682401

# %% [markdown]
# INSURANCE DATASET

# %%
import pandas as pd

x=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/refs/heads/main/insurance.csv")
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Create a new label encoding for 'sex' and 'smoker' columns, starting from 1
x['sex_encoded'] = le.fit_transform(x['sex']) + 1
x['smoker_encoded'] = le.fit_transform(x['smoker']) + 1

# Drop the original 'sex' and 'smoker' columns
x = x.drop(['sex', 'smoker'], axis=1)

# Now, 'sex_encoded' and 'smoker_encoded' contain the new label encoding without 0
x
# Out:
#       age     bmi  children     region      charges  sex_encoded  \
# 0      19  27.900         0  southwest  16884.92400            1
# 1      18  33.770         1  southeast   1725.55230            2
# 2      28  33.000         3  southeast   4449.46200            2
# 3      33  22.705         0  northwest  21984.47061            2
# 4      32  28.880         0  northwest   3866.85520            2
# ...   ...     ...       ...        ...          ...          ...
# 1333   50  30.970         3  northwest  10600.54830            2
# 1334   18  31.920         0  northeast   2205.98080            1
# 1335   18  36.850         0  southeast   1629.83350            1
# 1336   21  25.800         0  southwest   2007.94500            1
# 1337   61  29.070         0  northwest  29141.36030            1
#
#       smoker_encoded
# 0                  2
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 1333               1
# ...
